# %%
# %reload_ext autoreload
# %autoreload 2

import sys
sys.path.append('../src_jobs/')

# %%
import pickle
from itertools import repeat
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# from detector import WindowTransformerDetector

# %%
"""
returns: list of list of arrays containing the time series in the datasets in names
    only adds the series that are longer than the provided width (1024)
returns: weights for the time series in the list according to number of time series in the dataset
    all datasets are sampled at the same rate
"""
def load_series(names: list[str], split: str):
    series = list()
    counts = list()
    for name in names:
        with open(f"../data/processed/{name}_{split}.pickle", "rb") as f:
            raw = [a for a in pickle.load(f) if len(a) > 512]
            series.extend(np.array(a).astype(np.float32) for a in raw)
            counts.extend(repeat(1 / len(raw), len(raw)))
    counts = np.array(counts)
    return series, counts / counts.sum()

# %%
datasetname = "normalized_deviation_updated"
test_dataset, weights = load_series([datasetname], "TEST")
df_real = pd.DataFrame(test_dataset)

stats_df_real = pd.DataFrame()
stats_df_real["max"] = df_real.max(axis=1)
stats_df_real["min"] = df_real.min(axis=1)
stats_df_real["mean"] = df_real.mean(axis=1)
stats_df_real["stddev"] = df_real.std(axis=1)

gradient_df_real = df_real.diff(axis=1).abs()
stats_df_real["increment_max"] = gradient_df_real.max(axis=1)
stats_df_real["increment_min"] = gradient_df_real.min(axis=1)
stats_df_real["increment_mean"] = gradient_df_real.mean(axis=1)
stats_df_real["increment_stddev"] = gradient_df_real.std(axis=1)

# %%
from scipy.stats import skew, kurtosis

stats_df_real["skew"] = skew(df_real.iloc[0], bias=True)
stats_df_real["kurtosis"] = kurtosis(df_real.iloc[0], fisher=False, bias=True)
stats_df_real
# Out:
#          max        min          mean    stddev  increment_max  increment_min  \
# 0  12.352987 -11.329762 -3.948346e-09  0.999453        11.9681            0.0
#
#    increment_mean  increment_stddev      skew   kurtosis
# 0        0.044143          0.182534 -0.776235  47.798541

# %%
overall_stats = pd.read_csv('/workspaces/AICoE_Ramping_Artefacts/artifactory-master/data/stats_all.csv')

# %%
overall_stats.drop(columns=['Unnamed: 0'], inplace=True)
stats_df_real['datasetname'] = 'real'

overall_and_real = pd.concat([stats_df_real, overall_stats], ignore_index=True)

# %%
norm_overall_and_real = pd.DataFrame()
for column in overall_stats.columns[:-1]:
    norm_overall_and_real[column] = (overall_and_real[column] - overall_and_real[column].mean()) / overall_and_real[column].std()

norm_overall_and_real['datasetname'] = overall_and_real["datasetname"]

# %%
norm_stats_real = pd.DataFrame(columns=norm_overall_and_real.columns)
norm_stats_real.loc[0] = norm_overall_and_real.loc[0]
norm_stats_overall = norm_overall_and_real.loc[1:]
norm_stats_overall.reset_index(inplace=True)

# %%
norm_stats_overall.drop(columns=['index'], inplace=True)
# Out:
# /tmp/ipykernel_958/3555771828.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   norm_stats_overall.drop(columns=['index'], inplace=True)

# %%
norm_stats_overall_grouped = norm_stats_overall.groupby(['datasetname']).mean()

# %%
overall_and_real_grouped = overall_and_real.groupby(['datasetname']).mean()

# %%
real = overall_and_real_grouped.iloc[6]
rest = pd.concat([overall_and_real_grouped.iloc[:6], overall_and_real_grouped.iloc[7:]])
rest
# Out:
#                                                           max       min  \
# datasetname
# HouseholdPowerConsumption1                           3.646425 -2.075451
# HouseholdPowerConsumption2                           3.646425 -2.075451
# australian_electricity_demand_dataset                4.842094 -3.008433
# electricity_hourly_dataset                           4.007830 -2.986226
# electricity_load_diagrams                            4.057863 -1.963208
# london_smart_meters_dataset_without_missing_values  11.732024 -0.935920
# solar_10_minutes_dataset                             3.040003 -0.687743
# wind_farms_minutely_dataset_without_missing_values   7.677969 -0.777223
#
#                                                             mean    stddev  \
# datasetname
# HouseholdPowerConsumption1                          1.930000e-11  1.000349
# HouseholdPowerConsumption2                          1.930000e-11  1.000349
# australian_electricity_demand_dataset              -1.370415e-11  1.000002
# electricity_hourly_dataset                          6.675080e-08  1.000017
# electricity_load_diagrams                          -1.204722e-05  0.999989
# london_smart_meters_dataset_without_missing_values -4.852708e-12  1.000018
# solar_10_minutes_dataset                            1.773482e-06  0.999994
# wind_farms_minutely_dataset_without_missing_values  2.277345e-10  1.000001
#
#                                                     increment_max  \
# datasetname
# HouseholdPowerConsumption1                               2.208064
# HouseholdPowerConsumption2                               2.208064
# australian_electricity_demand_dataset                    2.110877
# electricity_hourly_dataset                               3.498252
# electricity_load_diagrams                                3.664582
# london_smart_meters_dataset_without_missing_values      10.399583
# solar_10_minutes_dataset                                 1.447440
# wind_farms_minutely_dataset_without_missing_values       5.831305
#
#                                                     increment_min  \
# datasetname
# HouseholdPowerConsumption1                           0.000000e+00
# HouseholdPowerConsumption2                           0.000000e+00
# australian_electricity_demand_dataset                4.947186e-07
# electricity_hourly_dataset                           0.000000e+00
# electricity_load_diagrams                            0.000000e+00
# london_smart_meters_dataset_without_missing_values   0.000000e+00
# solar_10_minutes_dataset                             0.000000e+00
# wind_farms_minutely_dataset_without_missing_values   0.000000e+00
#
#                                                     increment_mean  \
# datasetname
# HouseholdPowerConsumption1                                0.140969
# HouseholdPowerConsumption2                                0.140969
# australian_electricity_demand_dataset                     0.130896
# electricity_hourly_dataset                                0.274538
# electricity_load_diagrams                                 0.120715
# london_smart_meters_dataset_without_missing_values        0.428477
# solar_10_minutes_dataset                                  0.058718
# wind_farms_minutely_dataset_without_missing_values        0.016738
#
#                                                     increment_stddev  \
# datasetname
# HouseholdPowerConsumption1                                  0.220009
# HouseholdPowerConsumption2                                  0.220009
# australian_electricity_demand_dataset                       0.120768
# electricity_hourly_dataset                                  0.316935
# electricity_load_diagrams                                   0.165669
# london_smart_meters_dataset_without_missing_values          0.737539
# solar_10_minutes_dataset                                    0.110002
# wind_farms_minutely_dataset_without_missing_values          0.065179
#
#                                                         skew    kurtosis
# datasetname
# HouseholdPowerConsumption1                          0.643361    4.544977
# HouseholdPowerConsumption2                          0.643361    4.544977
# australian_electricity_demand_dataset               0.465713    3.282569
# electricity_hourly_dataset                          0.362436    3.393236
# electricity_load_diagrams                           0.363441    3.639756
# london_smart_meters_dataset_without_missing_values  3.319336   25.107594
# solar_10_minutes_dataset                            1.161848    2.864924
# wind_farms_minutely_dataset_without_missing_values  4.927484  330.467983

# %%
real
# Out:
# max                 1.235299e+01
# min                -1.132976e+01
# mean               -3.948346e-09
# stddev              9.994529e-01
# increment_max       1.196810e+01
# increment_min       0.000000e+00
# increment_mean      4.414336e-02
# increment_stddev    1.825335e-01
# skew               -7.762350e-01
# kurtosis            4.779854e+01
# Name: real, dtype: float64

# %%
overall_and_real_grouped
# Out:
#                                                           max        min  \
# datasetname
# HouseholdPowerConsumption1                           3.646425  -2.075451
# HouseholdPowerConsumption2                           3.646425  -2.075451
# australian_electricity_demand_dataset                4.842094  -3.008433
# electricity_hourly_dataset                           4.007830  -2.986226
# electricity_load_diagrams                            4.057863  -1.963208
# london_smart_meters_dataset_without_missing_values  11.732024  -0.935920
# real                                                12.352987 -11.329762
# solar_10_minutes_dataset                             3.040003  -0.687743
# wind_farms_minutely_dataset_without_missing_values   7.677969  -0.777223
#
#                                                             mean    stddev  \
# datasetname
# HouseholdPowerConsumption1                          1.930000e-11  1.000349
# HouseholdPowerConsumption2                          1.930000e-11  1.000349
# australian_electricity_demand_dataset              -1.370415e-11  1.000002
# electricity_hourly_dataset                          6.675080e-08  1.000017
# electricity_load_diagrams                          -1.204722e-05  0.999989
# london_smart_meters_dataset_without_missing_values -4.852708e-12  1.000018
# real                                               -3.948346e-09  0.999453
# solar_10_minutes_dataset                            1.773482e-06  0.999994
# wind_farms_minutely_dataset_without_missing_values  2.277345e-10  1.000001
#
#                                                     increment_max  \
# datasetname
# HouseholdPowerConsumption1                               2.208064
# HouseholdPowerConsumption2                               2.208064
# australian_electricity_demand_dataset                    2.110877
# electricity_hourly_dataset                               3.498252
# electricity_load_diagrams                                3.664582
# london_smart_meters_dataset_without_missing_values      10.399583
# real                                                    11.968100
# solar_10_minutes_dataset                                 1.447440
# wind_farms_minutely_dataset_without_missing_values       5.831305
#
#                                                     increment_min  \
# datasetname
# HouseholdPowerConsumption1                           0.000000e+00
# HouseholdPowerConsumption2                           0.000000e+00
# australian_electricity_demand_dataset                4.947186e-07
# electricity_hourly_dataset                           0.000000e+00
# electricity_load_diagrams                            0.000000e+00
# london_smart_meters_dataset_without_missing_values   0.000000e+00
# real                                                 0.000000e+00
# solar_10_minutes_dataset                             0.000000e+00
# wind_farms_minutely_dataset_without_missing_values   0.000000e+00
#
#                                                     increment_mean  \
# datasetname
# HouseholdPowerConsumption1                                0.140969
# HouseholdPowerConsumption2                                0.140969
# australian_electricity_demand_dataset                     0.130896
# electricity_hourly_dataset                                0.274538
# electricity_load_diagrams                                 0.120715
# london_smart_meters_dataset_without_missing_values        0.428477
# real                                                      0.044143
# solar_10_minutes_dataset                                  0.058718
# wind_farms_minutely_dataset_without_missing_values        0.016738
#
#                                                     increment_stddev  \
# datasetname
# HouseholdPowerConsumption1                                  0.220009
# HouseholdPowerConsumption2                                  0.220009
# australian_electricity_demand_dataset                       0.120768
# electricity_hourly_dataset                                  0.316935
# electricity_load_diagrams                                   0.165669
# london_smart_meters_dataset_without_missing_values          0.737539
# real                                                        0.182534
# solar_10_minutes_dataset                                    0.110002
# wind_farms_minutely_dataset_without_missing_values          0.065179
#
#                                                         skew    kurtosis
# datasetname
# HouseholdPowerConsumption1                          0.643361    4.544977
# HouseholdPowerConsumption2                          0.643361    4.544977
# australian_electricity_demand_dataset               0.465713    3.282569
# electricity_hourly_dataset                          0.362436    3.393236
# electricity_load_diagrams                           0.363441    3.639756
# london_smart_meters_dataset_without_missing_values  3.319336   25.107594
# real                                               -0.776235   47.798541
# solar_10_minutes_dataset                            1.161848    2.864924
# wind_farms_minutely_dataset_without_missing_values  4.927484  330.467983

# %%
similarities = np.zeros(len(norm_stats_overall_grouped))
# max, min, mean, stddev, inc_max, inc_min, inc_mean, inc_stddev, 3rd_m, 4th_m --> weights
weights = [1, 1, 0, 0, 1, 1, 1, 1, 1, 1]
weight = [val/sum(weights) for val in weights]

for row in range(len(norm_stats_overall_grouped)):
    Dist   = np.sqrt(
                     sum( 
                         ((norm_stats_overall_grouped.iloc[row, norm_stats_overall_grouped.columns != 'datasetname'] - norm_stats_real.iloc[0, norm_stats_real.columns != 'datasetname']) * weight)**2
                         ) 
                    )
    similarities[row]=Dist

norm_stats_overall_grouped["euclidean_dist"] = similarities

# %%
overall_norm_sorted = norm_stats_overall_grouped.sort_values(by=["euclidean_dist"], ascending=True)

# %%
norm_stats_real
# Out:
#         max       min      mean   stddev increment_max increment_min  \
# 0  0.805495 -9.045215  0.015895 -4.22346      1.021762     -0.012102
#
#   increment_mean increment_stddev      skew  kurtosis datasetname
# 0      -1.284429        -0.915934 -0.795368  0.037637        real

# %%
overall_norm_sorted
# Out:
#                                                          max       min  \
# datasetname
# electricity_hourly_dataset                         -0.547375 -1.337759
# HouseholdPowerConsumption1                         -0.605963 -0.496418
# HouseholdPowerConsumption2                         -0.605963 -0.496418
# electricity_load_diagrams                          -0.539263 -0.392732
# wind_farms_minutely_dataset_without_missing_values  0.047608  0.702838
# london_smart_meters_dataset_without_missing_values  0.704828  0.556239
# solar_10_minutes_dataset                           -0.704273  0.785496
# australian_electricity_demand_dataset              -0.412128 -1.358273
#
#                                                         mean    stddev  \
# datasetname
# electricity_hourly_dataset                          0.019261 -0.894116
# HouseholdPowerConsumption1                          0.016084  1.067345
# HouseholdPowerConsumption2                          0.016084  1.067345
# electricity_load_diagrams                          -0.557647 -1.057198
# wind_farms_minutely_dataset_without_missing_values  0.016093 -0.987742
# london_smart_meters_dataset_without_missing_values  0.016082 -0.890147
# solar_10_minutes_dataset                            0.100542 -1.030176
# australian_electricity_demand_dataset               0.016082 -0.980954
#
#                                                     increment_max  \
# datasetname
# electricity_hourly_dataset                              -0.437058
# HouseholdPowerConsumption1                              -0.659276
# HouseholdPowerConsumption2                              -0.659276
# electricity_load_diagrams                               -0.408410
# wind_farms_minutely_dataset_without_missing_values      -0.035220
# london_smart_meters_dataset_without_missing_values       0.751606
# solar_10_minutes_dataset                                -0.790284
# australian_electricity_demand_dataset                   -0.676015
#
#                                                     increment_min  \
# datasetname
# electricity_hourly_dataset                              -0.012102
# HouseholdPowerConsumption1                              -0.012102
# HouseholdPowerConsumption2                              -0.012102
# electricity_load_diagrams                               -0.012102
# wind_farms_minutely_dataset_without_missing_values      -0.012102
# london_smart_meters_dataset_without_missing_values      -0.012102
# solar_10_minutes_dataset                                -0.012102
# australian_electricity_demand_dataset                   30.038346
#
#                                                     increment_mean  \
# datasetname
# electricity_hourly_dataset                                0.035625
# HouseholdPowerConsumption1                               -0.729665
# HouseholdPowerConsumption2                               -0.729665
# electricity_load_diagrams                                -0.845708
# wind_farms_minutely_dataset_without_missing_values       -1.441450
# london_smart_meters_dataset_without_missing_values        0.917623
# solar_10_minutes_dataset                                 -1.200925
# australian_electricity_demand_dataset                    -0.787380
#
#                                                     increment_stddev  \
# datasetname
# electricity_hourly_dataset                                 -0.450777
# HouseholdPowerConsumption1                                 -0.786235
# HouseholdPowerConsumption2                                 -0.786235
# electricity_load_diagrams                                  -0.974301
# wind_farms_minutely_dataset_without_missing_values         -1.322091
# london_smart_meters_dataset_without_missing_values          1.004910
# solar_10_minutes_dataset                                   -1.166961
# australian_electricity_demand_dataset                      -1.129703
#
#                                                         skew  kurtosis  \
# datasetname
# electricity_hourly_dataset                         -0.462102 -0.027395
# HouseholdPowerConsumption1                         -0.379881 -0.025708
# HouseholdPowerConsumption2                         -0.379881 -0.025708
# electricity_load_diagrams                          -0.461808 -0.027033
# wind_farms_minutely_dataset_without_missing_values  0.873996  0.451609
# london_smart_meters_dataset_without_missing_values  0.403323  0.004406
# solar_10_minutes_dataset                           -0.228130 -0.028168
# australian_electricity_demand_dataset              -0.431875 -0.027557
#
#                                                     euclidean_dist
# datasetname
# electricity_hourly_dataset                                1.011168
# HouseholdPowerConsumption1                                1.106806
# HouseholdPowerConsumption2                                1.106806
# electricity_load_diagrams                                 1.111239
# wind_farms_minutely_dataset_without_missing_values        1.249149
# london_smart_meters_dataset_without_missing_values        1.263970
# solar_10_minutes_dataset                                  1.266157
# australian_electricity_demand_dataset                     3.886902
